# %% [markdown]
# # Analiza wydatków na jedzenie w Polsce na przestrzeni lat 1999-2020

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data_path_ludnosc = "../ludnosc.csv"
data_path_gminy = "../gminy.csv"
df_ludnosc = pd.read_csv(data_path_ludnosc, sep=";", decimal=',')
df_ludnosc = df_ludnosc[df_ludnosc['Wartosc'].notna()]

# %%
#przygotowanie tabeli
food_expenses = df_ludnosc[(df_ludnosc.Kategoria == "Wydatki") & (df_ludnosc.Nazwa == "POLSKA") & (df_ludnosc["Jednostka miary"] == "zł")]
food_expenses  = food_expenses[food_expenses.Rok != 1998]
food_expenses  = food_expenses[(food_expenses.Zmienna != "ogółem (BAEL)") & (food_expenses.Zmienna != "towary i usługi konsumpcyjne (BAEL)")]

# %% [markdown]
# ## Wydatki na żywność i napoje bezalkoholowe w stosunku do całkowitych wydatków na towary i usługi konsumpcyjne

# %%
food_expenses_vs_total = food_expenses[(food_expenses.Zmienna == "żywność i napoje bezalkoholowe") | (food_expenses.Zmienna == "towary i usługi konsumpcyjne")]
food_expenses_vs_total = food_expenses_vs_total.drop(['Kod','Unnamed: 8'], axis=1)
food_expenses_vs_total = food_expenses_vs_total.groupby(['Rok','Zmienna']).sum().reset_index()
food = food_expenses_vs_total[food_expenses_vs_total.Zmienna == "żywność i napoje bezalkoholowe"].reset_index()
total = food_expenses_vs_total[food_expenses_vs_total.Zmienna == "towary i usługi konsumpcyjne"].reset_index()
final_array = pd.DataFrame(columns=['Rok','%Udział'])
final_array['Rok'] = food['Rok']
final_array['%Udział'] = (food['Wartosc']/total['Wartosc']).multiply(100)
final_array['%Udział']
print(final_array)
plt.figure(figsize=(20,5))
plt.title('Stosunek wydatków na żywność do całkowitych wydatków')
plt.xlabel('Rok')
plt.ylabel('Udział procentowy')
plt.xlim(1999,2020)
plt.grid(True)
plt.xticks(final_array['Rok'])
plt.plot(final_array['Rok'], final_array['%Udział'], color='Orange')
# Out:
#      Rok    %Udział
# 0   1999  32.332359
# 1   2000  31.988158
# 2   2001  32.223588
# 3   2002  30.809413
# 4   2003  29.013164
# 5   2004  29.307573
# 6   2005  29.379267
# 7   2006  28.363927
# 8   2007  27.820470
# 9   2008  26.711506
# 10  2009  26.270982
# 11  2010  26.024529
# 12  2011  26.149635
# 13  2012  26.248769
# 14  2013  25.980816
# 15  2014  25.526841
# 16  2015  25.152698
# 17  2016  25.256966
# 18  2017  25.412090
# 19  2018  25.914618
# 20  2019  26.169010
# 21  2020  28.747821

# %% [markdown]
# ## Wydatki na napoje alkoholowe i wyroby tytoniowe vs. żywność i napoje bezalkoholowe

# %%
food_expenses_vs_alco = food_expenses[(food_expenses.Zmienna == "żywność i napoje bezalkoholowe") | (food_expenses.Zmienna == "napoje alkoholowe i wyroby tytoniowe")]
food_expenses_vs_alco = food_expenses_vs_alco.drop(['Kod','Unnamed: 8'], axis=1)
food_expenses_vs_alco = food_expenses_vs_alco.groupby(['Rok','Zmienna']).sum().reset_index()
alco = food_expenses_vs_alco[food_expenses_vs_alco.Zmienna == "napoje alkoholowe i wyroby tytoniowe"].reset_index()
non_alco = food_expenses_vs_alco[food_expenses_vs_alco.Zmienna == "żywność i napoje bezalkoholowe"].reset_index()
final_array_alco = pd.DataFrame(columns=['Rok','Udzial'])
final_array_alco['Rok'] = food['Rok']
final_array_alco['Udzial'] = alco['Wartosc']/non_alco['Wartosc']
final_array_alco['Udzial'].multiply(100)
print(final_array_alco)
plt.figure(figsize=(20,5))
plt.title('Stosunek wydatków na używki w stosunku do wydatków na żywność i napoje bezalkoholowe')
plt.xlabel('Rok')
plt.ylabel('Udział procentowy')
plt.xlim(1999,2020)
plt.grid(True)
plt.xticks(final_array_alco['Rok'])
plt.plot(final_array_alco['Rok'], final_array_alco['Udzial'], color='Orange')
# Out:
#      Rok    Udzial
# 0   1999  0.101394
# 1   2000  0.097310
# 2   2001  0.098389
# 3   2002  0.101132
# 4   2003  0.102593
# 5   2004  0.097447
# 6   2005  0.097115
# 7   2006  0.098907
# 8   2007  0.101219
# 9   2008  0.103011
# 10  2009  0.108547
# 11  2010  0.109450
# 12  2011  0.107858
# 13  2012  0.107864
# 14  2013  0.103268
# 15  2014  0.103440
# 16  2015  0.103156
# 17  2016  0.102271
# 18  2017  0.098136
# 19  2018  0.100363
# 20  2019  0.100843
# 21  2020  0.103823

# %% [markdown]
# ## Korelacja wydatków

# %%
corr_df = food_expenses[(food_expenses.Zmienna != "ogółem") & (food_expenses.Zmienna != "towary i usługi konsumpcyjne")]
corr_df = corr_df.drop(['Jednostka miary','Kod','Atrybut','Unnamed: 8'], axis=1).reset_index()
corr_df = corr_df.pivot(index='Rok',columns='Zmienna', values='Wartosc')
corr_df = corr_df.corr()
plt.figure(figsize=(16, 12))
plt.title('Korelacja wydatków')
sns.heatmap(corr_df, vmin=-1, vmax=1, annot=True);
corr_df
# Out:
# Zmienna                                             edukacja  \
# Zmienna
# edukacja                                            1.000000
# napoje alkoholowe i wyroby tytoniowe                0.749919
# odzież i obuwie                                     0.664436
# pozostałe wydatki na towary i usługi                0.729950
# rekreacja i kultura                                 0.721221
# restauracje i hotele                                0.674130
# transport                                           0.782356
# użytkowanie mieszkania lub domu i nośniki energii   0.716060
# wyposażenie mieszkania i prowadzenie gospodarst...  0.736557
# zdrowie                                             0.719974
# łączność                                            0.678012
# żywność i napoje bezalkoholowe                      0.746491
#
# Zmienna                                             napoje alkoholowe i wyroby tytoniowe  \
# Zmienna
# edukacja                                                                        0.749919
# napoje alkoholowe i wyroby tytoniowe                                            1.000000
# odzież i obuwie                                                                 0.871801
# pozostałe wydatki na towary i usługi                                            0.953567
# rekreacja i kultura                                                             0.882551
# restauracje i hotele                                                            0.866535
# transport                                                                       0.950118
# użytkowanie mieszkania lub domu i nośniki energii                               0.948384
# wyposażenie mieszkania i prowadzenie gospodarst...                              0.952984
# zdrowie                                                                         0.955050
# łączność                                                                        0.884786
# żywność i napoje bezalkoholowe                                                  0.986447
#
# Zmienna                                             odzież i obuwie  \
# Zmienna
# edukacja                                                   0.664436
# napoje alkoholowe i wyroby tytoniowe                       0.871801
# odzież i obuwie                                            1.000000
# pozostałe wydatki na towary i usługi                       0.932615
# rekreacja i kultura                                        0.924225
# restauracje i hotele                                       0.889793
# transport                                                  0.923028
# użytkowanie mieszkania lub domu i nośniki energii          0.940293
# wyposażenie mieszkania i prowadzenie gospodarst...         0.894227
# zdrowie                                                    0.942864
# łączność                                                   0.893993
# żywność i napoje bezalkoholowe                             0.871678
#
# Zmienna                                             pozostałe wydatki na towary i usługi  \
# Zmienna
# edukacja                                                                        0.729950
# napoje alkoholowe i wyroby tytoniowe                                            0.953567
# odzież i obuwie                                                                 0.932615
# pozostałe wydatki na towary i usługi                                            1.000000
# rekreacja i kultura                                                             0.848534
# restauracje i hotele                                                            0.965005
# transport                                                                       0.947710
# użytkowanie mieszkania lub domu i nośniki energii                               0.951096
# wyposażenie mieszkania i prowadzenie gospodarst...                              0.968196
# zdrowie                                                                         0.986668
# łączność                                                                        0.928098
# żywność i napoje bezalkoholowe                                                  0.978309
#
# Zmienna                                             rekreacja i kultura  \
# Zmienna
# edukacja                                                       0.721221
# napoje alkoholowe i wyroby tytoniowe                           0.882551
# odzież i obuwie                                                0.924225
# pozostałe wydatki na towary i usługi                           0.848534
# rekreacja i kultura                                            1.000000
# restauracje i hotele                                           0.749890
# transport                                                      0.925153
# użytkowanie mieszkania lub domu i nośniki energii              0.925755
# wyposażenie mieszkania i prowadzenie gospodarst...             0.848203
# zdrowie                                                        0.896321
# łączność                                                       0.821153
# żywność i napoje bezalkoholowe                                 0.843215
#
# Zmienna                                             restauracje i hotele  \
# Zmienna
# edukacja                                                        0.674130
# napoje alkoholowe i wyroby tytoniowe                            0.866535
# odzież i obuwie                                                 0.889793
# pozostałe wydatki na towary i usługi                            0.965005
# rekreacja i kultura                                             0.749890
# restauracje i hotele                                            1.000000
# transport                                                       0.884411
# użytkowanie mieszkania lub domu i nośniki energii               0.874640
# wyposażenie mieszkania i prowadzenie gospodarst...              0.924761
# zdrowie                                                         0.931858
# łączność                                                        0.849024
# żywność i napoje bezalkoholowe                                  0.916814
#
# Zmienna                                             transport  \
# Zmienna
# edukacja                                             0.782356
# napoje alkoholowe i wyroby tytoniowe                 0.950118
# odzież i obuwie                                      0.923028
# pozostałe wydatki na towary i usługi                 0.947710
# rekreacja i kultura                                  0.925153
# restauracje i hotele                                 0.884411
# transport                                            1.000000
# użytkowanie mieszkania lub domu i nośniki energii    0.942989
# wyposażenie mieszkania i prowadzenie gospodarst...   0.950919
# zdrowie                                              0.945680
# łączność                                             0.860940
# żywność i napoje bezalkoholowe                       0.945991
#
# Zmienna                                             użytkowanie mieszkania lub domu i nośniki energii  \
# Zmienna
# edukacja                                                                                     0.716060
# napoje alkoholowe i wyroby tytoniowe                                                         0.948384
# odzież i obuwie                                                                              0.940293
# pozostałe wydatki na towary i usługi                                                         0.951096
# rekreacja i kultura                                                                          0.925755
# restauracje i hotele                                                                         0.874640
# transport                                                                                    0.942989
# użytkowanie mieszkania lub domu i nośniki energii                                            1.000000
# wyposażenie mieszkania i prowadzenie gospodarst...                                           0.894484
# zdrowie                                                                                      0.977639
# łączność                                                                                     0.938120
# żywność i napoje bezalkoholowe                                                               0.935497
#
# Zmienna                                             wyposażenie mieszkania i prowadzenie gospodarstwa domowego  \
# Zmienna
# edukacja                                                                                     0.736557
# napoje alkoholowe i wyroby tytoniowe                                                         0.952984
# odzież i obuwie                                                                              0.894227
# pozostałe wydatki na towary i usługi                                                         0.968196
# rekreacja i kultura                                                                          0.848203
# restauracje i hotele                                                                         0.924761
# transport                                                                                    0.950919
# użytkowanie mieszkania lub domu i nośniki energii                                            0.894484
# wyposażenie mieszkania i prowadzenie gospodarst...                                           1.000000
# zdrowie                                                                                      0.947557
# łączność                                                                                     0.855213
# żywność i napoje bezalkoholowe                                                               0.970362
#
# Zmienna                                              zdrowie  łączność  \
# Zmienna
# edukacja                                            0.719974  0.678012
# napoje alkoholowe i wyroby tytoniowe                0.955050  0.884786
# odzież i obuwie                                     0.942864  0.893993
# pozostałe wydatki na towary i usługi                0.986668  0.928098
# rekreacja i kultura                                 0.896321  0.821153
# restauracje i hotele                                0.931858  0.849024
# transport                                           0.945680  0.860940
# użytkowanie mieszkania lub domu i nośniki energii   0.977639  0.938120
# wyposażenie mieszkania i prowadzenie gospodarst...  0.947557  0.855213
# zdrowie                                             1.000000  0.949675
# łączność                                            0.949675  1.000000
# żywność i napoje bezalkoholowe                      0.968682  0.899254
#
# Zmienna                                             żywność i napoje bezalkoholowe
# Zmienna
# edukacja                                                                  0.746491
# napoje alkoholowe i wyroby tytoniowe                                      0.986447
# odzież i obuwie                                                           0.871678
# pozostałe wydatki na towary i usługi                                      0.978309
# rekreacja i kultura                                                       0.843215
# restauracje i hotele                                                      0.916814
# transport                                                                 0.945991
# użytkowanie mieszkania lub domu i nośniki energii                         0.935497
# wyposażenie mieszkania i prowadzenie gospodarst...                        0.970362
# zdrowie                                                                   0.968682
# łączność                                                                  0.899254
# żywność i napoje bezalkoholowe                                            1.000000

# %% [markdown]
# ## Stosunek wydatków do dochodów w poszczególnych województwach w 2019 i 2020 roku

# %%
spendings_df = df_ludnosc[(df_ludnosc.Zmienna == "ogółem") & (df_ludnosc.Kategoria == "Wydatki") & (df_ludnosc["Jednostka miary"] == "zł") & ((df_ludnosc["Rok"] == 2019)|(df_ludnosc["Rok"] == 2020))]
spendings_df = spendings_df.groupby(['Nazwa','Rok']).sum()
spendings_df =  spendings_df.drop(['Unnamed: 8'], axis=1)
incomes_df =  df_ludnosc[(df_ludnosc.Zmienna == "ogółem") & (df_ludnosc.Kategoria == "Dochody") & (df_ludnosc["Jednostka miary"] == "zł") & ((df_ludnosc["Rok"] == 2019)|(df_ludnosc["Rok"] == 2020))]
incomes_df = incomes_df.groupby(['Nazwa','Rok']).sum()
incomes_df = incomes_df.drop(['Unnamed: 8'], axis=1)
spendings_vs_incomes = pd.merge(spendings_df, incomes_df, on =['Nazwa','Rok'], how ='inner')
spendings_vs_incomes.rename(columns={"Kod_x": "Kod", 'Wartosc_x': 'Wydatki', "Wartosc_y": "Dochody"}, inplace=True)
spendings_vs_incomes = spendings_vs_incomes.drop('Kod_y', axis=1)
spendings_vs_incomes['Wydatki do dochodów'] = (spendings_vs_incomes['Wydatki'] / spendings_vs_incomes['Dochody'])
spendings_vs_incomes.sort_values(by=['Wydatki do dochodów','Nazwa'], ascending=False)
display(spendings_vs_incomes)
# Out:
#                               Kod  Wydatki  Dochody  Wydatki do dochodów
# Nazwa               Rok
# DOLNOŚLĄSKIE        2019   200000  1382.62  1955.20             0.707150
#                     2020   200000  1355.29  2031.24             0.667223
# KUJAWSKO-POMORSKIE  2019   400000  1232.32  1770.82             0.695904
#                     2020   400000  1168.59  1845.34             0.633265
# LUBELSKIE           2019   600000  1114.35  1556.76             0.715814
#                     2020   600000  1132.57  1679.02             0.674542
# LUBUSKIE            2019   800000  1223.71  1794.12             0.682067
#                     2020   800000  1157.30  1971.47             0.587024
# MAZOWIECKIE         2019  1400000  1476.26  2108.01             0.700310
#                     2020  1400000  1443.01  2240.52             0.644051
# MAŁOPOLSKIE         2019  1200000  1077.73  1773.08             0.607829
#                     2020  1200000  1041.52  1914.74             0.543949
# OPOLSKIE            2019  1600000  1332.12  1687.29             0.789503
#                     2020  1600000  1287.33  1711.34             0.752235
# PODKARPACKIE        2019  1800000  1015.69  1471.49             0.690246
#                     2020  1800000   930.94  1588.57             0.586024
# PODLASKIE           2019  2000000  1029.51  1741.70             0.591095
#                     2020  2000000  1020.37  1948.31             0.523721
# POLSKA              2019        0  1251.73  1819.14             0.688089
#                     2020        0  1209.58  1919.21             0.630249
# POMORSKIE           2019  2200000  1360.50  1859.98             0.731459
#                     2020  2200000  1328.72  1799.12             0.738539
# WARMIŃSKO-MAZURSKIE 2019  2800000  1006.90  1597.18             0.630424
#                     2020  2800000  1073.42  1884.05             0.569741
# WIELKOPOLSKIE       2019  3000000  1162.82  1806.98             0.643516
#                     2020  3000000  1123.35  1789.13             0.627875
# ZACHODNIOPOMORSKIE  2019  3200000  1263.35  1801.11             0.701429
#                     2020  3200000  1242.53  1862.09             0.667277
# ŁÓDZKIE             2019  1000000  1374.59  1809.65             0.759589
#                     2020  1000000  1225.52  1871.83             0.654718
# ŚLĄSKIE             2019  2400000  1330.36  1897.39             0.701153
#                     2020  2400000  1270.85  2050.36             0.619818
# ŚWIĘTOKRZYSKIE      2019  2600000  1059.05  1626.46             0.651138
#                     2020  2600000   994.00  1726.92             0.575591
